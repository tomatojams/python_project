# %%
def grade(a):
    if (a >= 90 and a <=100):
        return "A"
    elif(a >= 80 and a < 90):
        return "B"
    elif(a >= 70 and a < 80):
        return "C"
    elif(a >= 60 and a < 70):
        return "D"
    elif(a >= 0 and a < 60): 
        return "F"
    else:
        print("입력값이 잘못되었습니다.")

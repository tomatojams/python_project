# %% [markdown]
# **노트북 파일명** 07-cnn2

# %% [markdown]
# # Dropout

# %% [markdown]
# 런타임 유형: GPU 확인

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Sat Oct 14 21:17:28 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 537.42                 Driver Version: 537.42       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3070      WDDM  | 00000000:06:00.0  On |                  N/A |
# |  0%   48C    P8              19W / 220W |   1206MiB /  8192MiB |     26%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1192    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A      4384    C+G   ...les\Microsoft OneDrive\OneDrive.exe    N/A      |
# |    0   N/A  N/A      7132    C+G   ...72.0_x64__8wekyb3d8bbwe\GameBar.exe    N/A      |
# |    0   N/A  N/A      8476    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A      8592    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A      9020    C+G   ...2txyewy\StartMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A      9720    C+G   ...crosoft\Edge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     12300    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     13576    C+G   ...oogle\Chrome\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     14208    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     14616    C+G   ...ejd91yc\AdobeNotificationClient.exe    N/A      |
# |    0   N/A  N/A     17048    C+G   D:\Program Files\RaiDrive\RaiDrive.exe    N/A      |
# |    0   N/A  N/A     17264    C+G   ...telliJ IDEA 2023.2.2\bin\idea64.exe    N/A      |
# |    0   N/A  N/A     18008    C+G   ...on\117.0.2045.60\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     18872    C+G   ...\Local\slack\app-4.34.121\slack.exe    N/A      |
# |    0   N/A  N/A     22508    C+G   ...aam7r\AcrobatNotificationClient.exe    N/A      |
# |    0   N/A  N/A     22604    C+G   ...on\HEX\Creative Cloud UI Helper.exe    N/A      |
# |    0   N/A  N/A     23684    C+G   ...5n1h2txyewy\ShellExperienceHost.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# Dropout없이 CIFAR-10 학습

# %%
# tensorflow와 tf.keras를 임포트합니다
import tensorflow as tf
from tensorflow import keras

# 헬퍼(helper) 라이브러리를 임포트합니다
import numpy as np
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

class_names = ['airplain', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
NUM_CLASSES = 10

from tensorflow.keras.utils import to_categorical

if y_test.shape[1] == 1:
    x_train = x_train/255.
    x_test = x_test/255.
    y_train = to_categorical(y_train, NUM_CLASSES)
    y_test = to_categorical(y_test, NUM_CLASSES)

model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=30, validation_data=(x_test,y_test))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 15s 5ms/step - loss: 1.5899 - accuracy: 0.4115 - val_loss: 1.2451 - val_accuracy: 0.5456
# Epoch 2/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.0679 - accuracy: 0.6202 - val_loss: 0.9391 - val_accuracy: 0.6682
# Epoch 3/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8426 - accuracy: 0.7029 - val_loss: 0.8335 - val_accuracy: 0.7119
# Epoch 4/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7026 - accuracy: 0.7512 - val_loss: 0.7621 - val_accuracy: 0.7385
# Epoch 5/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6043 - accuracy: 0.7907 - val_loss: 0.7770 - val_accuracy: 0.7375
# Epoch 6/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5242 - accuracy: 0.8167 - val_loss: 0.7370 - val_accuracy: 0.7524
# Epoch 7/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4487 - accuracy: 0.8412 - val_loss: 0.7643 - val_accuracy: 0.7582
# Epoch 8/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.3947 - accuracy: 0.8611 - val_loss: 0.8178 - val_accuracy: 0.7575
# Epoch 9/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.3317 - accuracy: 0.8823 - val_loss: 0.8929 - val_accuracy: 0.7385
# Epoch 10/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2908 - accuracy: 0.8972 - val_loss: 0.8746 - val_accuracy: 0.7542
# Epoch 11/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2541 - accuracy: 0.9107 - val_loss: 0.9865 - val_accuracy: 0.7520
# Epoch 12/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.2304 - accuracy: 0.9168 - val_loss: 0.9909 - val_accuracy: 0.7492
# Epoch 13/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1976 - accuracy: 0.9304 - val_loss: 1.1222 - val_accuracy: 0.7511
# Epoch 14/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1899 - accuracy: 0.9328 - val_loss: 1.2471 - val_accuracy: 0.7409
# Epoch 15/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1752 - accuracy: 0.9390 - val_loss: 1.1727 - val_accuracy: 0.7546
# Epoch 16/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1691 - accuracy: 0.9405 - val_loss: 1.2571 - val_accuracy: 0.7481
# Epoch 17/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1646 - accuracy: 0.9433 - val_loss: 1.2907 - val_accuracy: 0.7411
# Epoch 18/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1493 - accuracy: 0.9484 - val_loss: 1.3748 - val_accuracy: 0.7484
# Epoch 19/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1513 - accuracy: 0.9477 - val_loss: 1.3852 - val_accuracy: 0.7493
# Epoch 20/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1407 - accuracy: 0.9515 - val_loss: 1.5392 - val_accuracy: 0.7349
# Epoch 21/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1446 - accuracy: 0.9510 - val_loss: 1.3817 - val_accuracy: 0.7471
# Epoch 22/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1293 - accuracy: 0.9556 - val_loss: 1.5299 - val_accuracy: 0.7486
# Epoch 23/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1308 - accuracy: 0.9559 - val_loss: 1.4974 - val_accuracy: 0.7446
# Epoch 24/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1277 - accuracy: 0.9564 - val_loss: 1.4820 - val_accuracy: 0.7411
# Epoch 25/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1241 - accuracy: 0.9578 - val_loss: 1.5753 - val_accuracy: 0.7412
# Epoch 26/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1245 - accuracy: 0.9582 - val_loss: 1.5671 - val_accuracy: 0.7348
# Epoch 27/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1198 - accuracy: 0.9599 - val_loss: 1.5743 - val_accuracy: 0.7425
# Epoch 28/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1169 - accuracy: 0.9605 - val_loss: 1.5979 - val_accuracy: 0.7436
# Epoch 29/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1161 - accuracy: 0.9612 - val_loss: 1.6243 - val_accuracy: 0.7491
# Epoch 30/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1180 - accuracy: 0.9608 - val_loss: 1.6223 - val_accuracy: 0.7361

# %%
# 학습 정확성 값과 검증 정확성 값을 플롯팅 합니다.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('train history')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# Fully connected 레이어에 dropout 0.5 적용

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history2 = model.fit(x_train, y_train, epochs=30, validation_data=(x_test,y_test))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.7675 - accuracy: 0.3446 - val_loss: 1.3358 - val_accuracy: 0.5069
# Epoch 2/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3583 - accuracy: 0.5137 - val_loss: 1.0902 - val_accuracy: 0.6032
# Epoch 3/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1751 - accuracy: 0.5867 - val_loss: 1.0349 - val_accuracy: 0.6433
# Epoch 4/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0693 - accuracy: 0.6271 - val_loss: 0.9156 - val_accuracy: 0.6824
# Epoch 5/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9778 - accuracy: 0.6623 - val_loss: 0.8589 - val_accuracy: 0.7032
# Epoch 6/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9110 - accuracy: 0.6844 - val_loss: 0.8652 - val_accuracy: 0.6988
# Epoch 7/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8614 - accuracy: 0.7036 - val_loss: 0.8438 - val_accuracy: 0.7175
# Epoch 8/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8184 - accuracy: 0.7192 - val_loss: 0.7643 - val_accuracy: 0.7364
# Epoch 9/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7835 - accuracy: 0.7310 - val_loss: 0.8004 - val_accuracy: 0.7277
# Epoch 10/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7525 - accuracy: 0.7443 - val_loss: 0.7513 - val_accuracy: 0.7395
# Epoch 11/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7211 - accuracy: 0.7543 - val_loss: 0.7515 - val_accuracy: 0.7411
# Epoch 12/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6937 - accuracy: 0.7617 - val_loss: 0.7277 - val_accuracy: 0.7566
# Epoch 13/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6758 - accuracy: 0.7716 - val_loss: 0.7367 - val_accuracy: 0.7542
# Epoch 14/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6619 - accuracy: 0.7744 - val_loss: 0.7696 - val_accuracy: 0.7506
# Epoch 15/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6395 - accuracy: 0.7816 - val_loss: 0.7414 - val_accuracy: 0.7469
# Epoch 16/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6250 - accuracy: 0.7845 - val_loss: 0.7082 - val_accuracy: 0.7651
# Epoch 17/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6107 - accuracy: 0.7903 - val_loss: 0.7041 - val_accuracy: 0.7730
# Epoch 18/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5907 - accuracy: 0.7972 - val_loss: 0.7152 - val_accuracy: 0.7620
# Epoch 19/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5778 - accuracy: 0.8036 - val_loss: 0.7042 - val_accuracy: 0.7683
# Epoch 20/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5627 - accuracy: 0.8076 - val_loss: 0.7182 - val_accuracy: 0.7667
# Epoch 21/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5486 - accuracy: 0.8103 - val_loss: 0.7402 - val_accuracy: 0.7723
# Epoch 22/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5426 - accuracy: 0.8148 - val_loss: 0.7187 - val_accuracy: 0.7707
# Epoch 23/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5231 - accuracy: 0.8223 - val_loss: 0.7343 - val_accuracy: 0.7746
# Epoch 24/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5271 - accuracy: 0.8197 - val_loss: 0.7241 - val_accuracy: 0.7788
# Epoch 25/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5121 - accuracy: 0.8261 - val_loss: 0.6965 - val_accuracy: 0.7765
# Epoch 26/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5038 - accuracy: 0.8279 - val_loss: 0.7136 - val_accuracy: 0.7801
# Epoch 27/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5031 - accuracy: 0.8303 - val_loss: 0.7155 - val_accuracy: 0.7806
# Epoch 28/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4866 - accuracy: 0.8306 - val_loss: 0.7791 - val_accuracy: 0.7685
# Epoch 29/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4799 - accuracy: 0.8365 - val_loss: 0.7457 - val_accuracy: 0.7739
# Epoch 30/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4674 - accuracy: 0.8400 - val_loss: 0.7485 - val_accuracy: 0.7763

# %%
# 학습 정확성 값과 검증 정확성 값을 플롯팅 합니다.
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# summarize history for accuracy
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('train history')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# # VGG-16

# %%
image_path = keras.utils.get_file("dog.jpg", "https://github.com/kotech1/computervision/blob/master/img/dog.jpg?raw=true")
# Out:
# Downloading data from https://github.com/kotech1/computervision/blob/master/img/dog.jpg?raw=true
# 163759/163759 [==============================] - 0s 0us/step

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

model = VGG16(weights='imagenet', include_top=True)


img = keras.utils.load_img(image_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 16s 0us/step
# 1/1 [==============================] - 1s 989ms/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n02110063', 'malamute', 0.31755316), ('n02110185', 'Siberian_husky', 0.21920876), ('n02109961', 'Eskimo_dog', 0.15373056)]

# %%
plt.imshow(img)

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## imagenette

# %% [markdown]
# subset of imageNet
# https://github.com/fastai/imagenette

# %%
# !wget https://s3.amazonaws.com/fast-ai-imageclas/imagenette2-320.tgz
# Out:
# 'wget'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# !ls
# Out:
# 'ls'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# !tar xvzf imagenette2-320.tgz
# Out:
# tar: Error opening archive: Failed to open 'imagenette2-320.tgz'

# %%
json_path = keras.utils.get_file("imagenet_class_index.json", "https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json")

import json
# Opening JSON file
with open(json_path) as json_file:
    imagenet_class_index = json.load(json_file)

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow import keras
import numpy as np

SAVE_DIR = '.'
model = VGG16(weights=None, classes=10)
try:
  model.load_weights(SAVE_DIR+'/best_model.h5')
  print('load done')
except:
  pass
#print(model.summary())
from tensorflow.keras.optimizers import Adam
model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.0005), metrics=['accuracy'])

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

# create a data generator
datagen = ImageDataGenerator(preprocessing_function = preprocess_input)

DATA_DIR = 'imagenette2-320'

# load and iterate training dataset
train_it = datagen.flow_from_directory(DATA_DIR+'/train/', target_size=(224, 224), class_mode='categorical', batch_size=64)
# load and iterate validation dataset
val_it = datagen.flow_from_directory(DATA_DIR+'/val/', target_size=(224, 224), class_mode='categorical', batch_size=64)
# load and iterate test dataset
#test_it = datagen.flow_from_directory(DATA_DIR+'/test/', class_mode='binary', batch_size=64)

checkpoint = ModelCheckpoint(SAVE_DIR+"/best_model.h5", monitor='loss', verbose=1,
    save_best_only=True, mode='auto', period=1)

from tensorflow.keras.callbacks import Callback

class LrReducer(Callback):
    def __init__(self, patience=0, reduce_rate=0.5, reduce_nb=10, verbose=1):
        super(Callback, self).__init__()
        self.patience = patience
        self.wait = 0
        self.best_score = -1.
        self.reduce_rate = reduce_rate
        self.current_reduce_nb = 0
        self.reduce_nb = reduce_nb
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        #current_score = logs.get('val_accuracy')
        current_score = logs.get('accuracy')
        if current_score > self.best_score:
            self.best_score = current_score
            self.wait = 0
            if self.verbose > 0:
                print('---current best score: %.3f' % current_score)
        else:
            if self.wait >= self.patience:
                self.current_reduce_nb += 1
                if self.current_reduce_nb <= 10:
                    lr = keras.backend.get_value(self.model.optimizer.lr)
                    keras.backend.set_value(self.model.optimizer.lr, lr*self.reduce_rate)
                    if self.verbose > 0:
                        print('---lr decreasing: %e' % (lr*self.reduce_rate))
                else:
                    if self.verbose > 0:
                        print("Epoch %d: early stopping" % (epoch))
                    self.model.stop_training = True
            self.wait += 1
lrreducer = LrReducer(patience=5)
# fit model
history = model.fit(train_it, steps_per_epoch=16, validation_data=val_it,
          validation_steps=8,
          epochs=100, callbacks=[checkpoint,lrreducer])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 27
#      24 DATA_DIR = 'imagenette2-320'
#      26 # load and iterate training dataset
# ---> 27 train_it = datagen.flow_from_directory(DATA_DIR+'/train/', target_size=(224, 224), class_mode='categorical', batch_size=64)
#      28 # load and iterate validation dataset
#      29 val_it = datagen.flow_from_directory(DATA_DIR+'/val/', target_size=(224, 224), class_mode='categorical', batch_size=64)
#
# File F:\Anaconda3_envs\tensor2\lib\site-packages\keras\preprocessing\image.py:1650, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1564 def flow_from_directory(
#    1565     self,
#    1566     directory,
#    (...)
#    1580     keep_aspect_ratio=False,
#    1581 ):
#    1582     """Takes the path to a directory & generates batches of augmented data.
#    1583
#    1584     Args:
#    (...)
#    1648             and `y` is a numpy array of corresponding labels.
#    1649     """
# -> 1650     return DirectoryIterator(
#    1651         directory,
#    1652         self,
#    1653         target_size=target_size,
#    1654         color_mode=color_mode,
#    1655         keep_aspect_ratio=keep_aspect_ratio,
#    1656         classes=classes,
#    1657         class_mode=class_mode,
#    1658         data_format=self.data_format,
#    1659         batch_size=batch_size,
#    1660         shuffle=shuffle,
#    1661         seed=seed,
#    1662         save_to_dir=save_to_dir,
#    1663         save_prefix=save_prefix,
#    1664         save_format=save_format,
#    1665         follow_links=follow_links,
#    1666         subset=subset,
#    1667         interpolation=interpolation,
#    1668         dtype=self.dtype,
#    1669     )
#
# File F:\Anaconda3_envs\tensor2\lib\site-packages\keras\preprocessing\image.py:563, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     561 if not classes:
#     562     classes = []
# --> 563     for subdir in sorted(os.listdir(directory)):
#     564         if os.path.isdir(os.path.join(directory, subdir)):
#     565             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'imagenette2-320/train/'

# %%
# 학습 정확성 값과 검증 정확성 값을 플롯팅 합니다.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# 학습 손실 값과 검증 손실 값을 플롯팅 합니다.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# imagenette 클래스 명 정의

# %%
class_indices = list(train_it.class_indices.keys())
class_values = list(val_it.class_indices.values())
class_names=[]
for i in range(1000):
  if imagenet_class_index['{}'.format(i)][0] in class_indices:
    class_names.append(imagenet_class_index['{}'.format(i)][1])

# %%
train_it.class_indices
# Out:
# {'n01440764': 0,
#  'n02102040': 1,
#  'n02979186': 2,
#  'n03000684': 3,
#  'n03028079': 4,
#  'n03394916': 5,
#  'n03417042': 6,
#  'n03425413': 7,
#  'n03445777': 8,
#  'n03888257': 9}

# %%
model2 = keras.models.load_model(SAVE_DIR+"/best_model.h5")
model2.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 10)                40970
#
# =================================================================
# Total params: 134,301,514
# Trainable params: 134,301,514
# Non-trainable params: 0
# _________________________________________________________________

# %%
#image_path2 = 'imagenette2-320/val/n02102040/n02102040_7501.JPEG'
#image_path2 = 'imagenette2-320/val/n03028079/ILSVRC2012_val_00019711.JPEG'
image_path2 = 'imagenette2-320/val/n02102040/n02102040_6180.JPEG'
img = keras.utils.load_img(image_path2, target_size=(224, 224))
x = keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model2.predict(x)

plt.imshow(img)
class_names[preds[0].argmax()]
# Out:
# 1/1 [==============================] - 0s 338ms/step
# 'English_springer'

# %%
img = train_it[0][0][0]
plt.imshow(img)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# 여러가지 기본 고성능 모델
#
# https://keras.io/api/applications/

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input, decode_predictions

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.applications import ResNet152V2

from tensorflow.keras.applications import MobileNetV2

from tensorflow.keras.applications.efficientnet import EfficientNetB0, EfficientNetB1

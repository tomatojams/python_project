# %% [markdown]
# 필요한 패키지를 가져옵니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import mnist

# %% [markdown]
# 숫자 손글씨 데이터셋을 불러옵니다.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print('x_train shape : ' + str(x_train.shape))
print('y_train shape : ' + str(y_train.shape))
print('x_test shape : ' + str(x_test.shape))
print('y_test shape : ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# x_train shape : (60000, 28, 28)
# y_train shape : (60000,)
# x_test shape : (10000, 28, 28)
# y_test shape : (10000,)

# %% [markdown]
# 테스트할 샘플 하나를 살펴봅니다.

# %%
plt.imshow(x_test[0], cmap='gray')

# %% [markdown]
# 인공지능 모델이 이 이미지를 입력받았을 때, 해당하는 숫자를 출력할 수 있도록 만드는 것이 목표입니다. 우리는 y_test 라벨값도 가지고 있어서 바로 확인은 할 수 있으나, 모델 학습 시에는 사용이 되지 않으며, 시험 평가할 때만 사용됩니다.

# %%
print(y_test[0])
# Out:
# 7

# %% [markdown]
# 그럼 모델 학습에 사용할 훈련셋의 이미지와 라벨을 확인해보겠습니다.

# %%
fig, axes = plt.subplots(nrows=10, ncols=10, figsize=(10, 13), 
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap = 'gray')
    ax.set_title(y_train[i])

plt.show()

# %% [markdown]
# 모델 학습에 용이하도록 다음과 같이 데이터 전처리를 수행합니다.
#
# *   데이터 전처리
#     * 3차원(샘플수, 세로, 가로)를 2차원(샘플수, 벡터수)으로 변경
#     * 정수를 실수로 변경
#     * 0 ~ 255 사이의 수치를 0.0 ~ 1.0 사이로 정규화 수행
# *   라벨 전처리
#     * 0 ~ 9 라벨에 대한 원핫인코딩 수행

# %%
x_train = x_train.reshape(60000, 784).astype('float32') / 255.0
x_test = x_test.reshape(10000, 784).astype('float32') / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# 모델은 다음과 같이 구성하였습니다.
#
# * 입력: 1차원의 784개 벡터
# * 출력: 10개 벡터
# * 출력층의 활성화 함수: 소프트맥스
# * 손실함수: categorical_crossentropy
# * 최적화기: adam
# * 평가 메트릭: accuracy

# %%
model = Sequential([
    Dense(64, input_dim=28*28, activation='relu'), 
    Dense(32, activation='relu'), 
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# 모델 네트워크 아키텍처 구성을 그려보겠습니다.

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# 준비된 훈련셋으로 모델을 학습시킵니다. fit()는 매 에포크에 해당하는 손실값과 평가 메트릭 수치를 반환합니다.

# %%
hist = model.fit(x_train, y_train,
                 batch_size=32,
                 epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.2946 - accuracy: 0.9149
# Epoch 2/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1357 - accuracy: 0.9594
# Epoch 3/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0964 - accuracy: 0.9708
# Epoch 4/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0769 - accuracy: 0.9763
# Epoch 5/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0643 - accuracy: 0.9800
# Epoch 6/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0528 - accuracy: 0.9837
# Epoch 7/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0463 - accuracy: 0.9852
# Epoch 8/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0395 - accuracy: 0.9875
# Epoch 9/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0330 - accuracy: 0.9891
# Epoch 10/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0308 - accuracy: 0.9901
# Epoch 11/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0259 - accuracy: 0.9917
# Epoch 12/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0249 - accuracy: 0.9921
# Epoch 13/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0232 - accuracy: 0.9923
# Epoch 14/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0206 - accuracy: 0.9930
# Epoch 15/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0180 - accuracy: 0.9944
# Epoch 16/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0168 - accuracy: 0.9942
# Epoch 17/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0160 - accuracy: 0.9948
# Epoch 18/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0152 - accuracy: 0.9949
# Epoch 19/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0140 - accuracy: 0.9950
# Epoch 20/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0112 - accuracy: 0.9963
# Epoch 21/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0141 - accuracy: 0.9956
# Epoch 22/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0114 - accuracy: 0.9962
# Epoch 23/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0132 - accuracy: 0.9959
# Epoch 24/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0095 - accuracy: 0.9969
# Epoch 25/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0112 - accuracy: 0.9962
# Epoch 26/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0116 - accuracy: 0.9959
# Epoch 27/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0089 - accuracy: 0.9969
# Epoch 28/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0100 - accuracy: 0.9967
# Epoch 29/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0104 - accuracy: 0.9965
# Epoch 30/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0086 - accuracy: 0.9973
# Epoch 31/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0094 - accuracy: 0.9969
# Epoch 32/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0090 - accuracy: 0.9970
# Epoch 33/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0090 - accuracy: 0.9971
# Epoch 34/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9976
# Epoch 35/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0093 - accuracy: 0.9968
# Epoch 36/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9974
# Epoch 37/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0077 - accuracy: 0.9973
# Epoch 38/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0086 - accuracy: 0.9974
# Epoch 39/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0072 - accuracy: 0.9977
# Epoch 40/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0078 - accuracy: 0.9976
# Epoch 41/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0074 - accuracy: 0.9974
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 43/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0074 - accuracy: 0.9975
# Epoch 44/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0058 - accuracy: 0.9983
# Epoch 45/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0077 - accuracy: 0.9977
# Epoch 46/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0068 - accuracy: 0.9978
# Epoch 47/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0090 - accuracy: 0.9973
# Epoch 48/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0070 - accuracy: 0.9978
# Epoch 49/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0071 - accuracy: 0.9978
# Epoch 50/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0056 - accuracy: 0.9981
# Epoch 51/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0062 - accuracy: 0.9980
# Epoch 52/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0075 - accuracy: 0.9976
# Epoch 53/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0055 - accuracy: 0.9984
# Epoch 54/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0082 - accuracy: 0.9976
# Epoch 55/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0061 - accuracy: 0.9981
# Epoch 56/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0055 - accuracy: 0.9982
# Epoch 57/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 58/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0066 - accuracy: 0.9979
# Epoch 59/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0071 - accuracy: 0.9979
# Epoch 60/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 61/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0088 - accuracy: 0.9974
# Epoch 62/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 0.9989
# Epoch 63/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0050 - accuracy: 0.9985
# Epoch 64/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0079 - accuracy: 0.9979
# Epoch 65/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 66/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0069 - accuracy: 0.9980
# Epoch 67/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 68/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0058 - accuracy: 0.9983
# Epoch 69/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0065 - accuracy: 0.9980
# Epoch 70/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0060 - accuracy: 0.9983
# Epoch 71/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 72/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0073 - accuracy: 0.9980
# Epoch 73/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 74/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9983
# Epoch 75/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0063 - accuracy: 0.9984
# Epoch 76/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 77/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0060 - accuracy: 0.9981
# Epoch 78/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0053 - accuracy: 0.9984
# Epoch 79/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9985
# Epoch 80/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0069 - accuracy: 0.9982
# Epoch 81/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0067 - accuracy: 0.9984
# Epoch 82/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 83/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0060 - accuracy: 0.9984
# Epoch 84/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0057 - accuracy: 0.9984
# Epoch 85/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 86/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 87/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 88/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0054 - accuracy: 0.9985
# Epoch 89/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0068 - accuracy: 0.9984
# Epoch 90/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 91/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0050 - accuracy: 0.9984
# Epoch 92/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0064 - accuracy: 0.9983
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0044 - accuracy: 0.9989
# Epoch 94/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 95/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 96/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0048 - accuracy: 0.9988
# Epoch 97/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 98/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 99/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0064 - accuracy: 0.9986
# Epoch 100/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0060 - accuracy: 0.9983

# %% [markdown]
# 학습 시 매 에포크에 해당하는 훈련셋의 손실값과 평가 메트릭 수치를 시각화 하여 확인할 수 있습니다.

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# 에포크를 반복할수록 훈련셋의 손실값은 계속 낮아지는 것을 확인할 수 있습니다. 최종 학습된 모델로 평가를 수행합니다.

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2808 - accuracy: 0.9759
# Test accuracy 0.9758999943733215
# Test loss 0.2808394134044647

# %% [markdown]
# 또한 시험셋으로 테스트한 결과를 제출하기 위해 모델 결과 파일을 저장합니다. 출력이 10개 클래스에 해당하는 벡터이므로, 분류한 클래스 정보를 얻기 위해 가장 높은 값을 가진 인덱스 값을 가지고 옵니다. 이 인덱스가 클래스를 의미하며, 이 값을 파일로 저장합니다.

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.argmax(axis=-1)
np.savetxt('y_pred.csv', y_pred, fmt='%d')

# %% [markdown]
# 훈련셋에만 적합된 모델 즉 오버피팅된 모델인지는 확인할 수가 없습니다. 다음 실습에서는 검증셋을 통해서 오버피팅을 모니터링하고, 오버피팅이 되기 전의 모델을 확보하는 방법에 대해서 알아보겠습니다.

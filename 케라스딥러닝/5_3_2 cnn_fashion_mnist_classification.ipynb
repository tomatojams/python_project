# %% [markdown]
# 필요한 패키지를 가져옵니다.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import urllib

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import fashion_mnist

# %% [markdown]
# 패션아이템 이미지 데이터셋을 불러옵니다.

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print('x_train shape : ' + str(x_train.shape))
print('y_train shape : ' + str(y_train.shape))
print('x_test shape : ' + str(x_test.shape))
print('y_test shape : ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# x_train shape : (60000, 28, 28)
# y_train shape : (60000,)
# x_test shape : (10000, 28, 28)
# y_test shape : (10000,)

# %% [markdown]
# 테스트할 샘플 하나를 살펴봅니다.

# %%
import matplotlib.pyplot as plt

plt.imshow(x_test[0], cmap='gray')

# %% [markdown]
# 인공지능 모델이 이 이미지를 입력받았을 때, 해당하는 숫자를 출력할 수 있도록 만드는 것이 목표입니다. 우리는 y_test 라벨값도 가지고 있어서 바로 확인은 할 수 있으나, 모델 학습 시에는 사용이 되지 않으며, 시험 평가할 때만 사용됩니다.

# %%
print(y_test[0])
# Out:
# 9

# %% [markdown]
# 패션아이템 이미지와 라벨의 숫자가 의미하는 아이템 이름과 함께 같이 가시화 시킵니다.

# %%
fig, axes = plt.subplots(nrows=10, ncols=10, figsize=(13, 15), 
                         subplot_kw={'xticks': [], 'yticks': []})

labels = ['T-shirt/top',
          'Trouser',
          'Pullover',
          'Dress',
          'Coat',
          'Sandal',
          'Shirt',
          'Sneaker',
          'Bag',
          'Ankle boot']

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap = 'gray')
    title = labels[y_train[i]]
    ax.set_title(title)

plt.show()

# %% [markdown]
# 모델 학습에 용이하도록 다음과 같이 데이터 전처리를 수행합니다.
#
# *   데이터 전처리
#     * 3차원(샘플수, 세로, 가로)를 4차원(샘플수, 세로, 가로, 채널)으로 변경
#     * 정수를 실수로 변경
#     * 0 ~ 255 사이의 수치를 0.0 ~ 1.0 사이로 정규화 수행
# *   라벨 전처리
#     * 0 ~ 9 라벨에 대한 원핫인코딩 수행

# %%
x_train = x_train.reshape(60000, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(10000, 28, 28, 1).astype('float32') / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# 모델은 다음과 같이 구성하였습니다.
#
# * 입력: 3차원 벡터 (세로 28, 가로 28, 채널 1)
# * 출력: 10개 벡터
# * 출력층의 활성화 함수: 소프트맥스
# * 손실함수: categorical_crossentropy
# * 최적화기: adam
# * 평가 메트릭: accuracy
#
# 컨볼루션 신경망을 구성하기 위해, 컨볼루션 레이어, 맥스풀링 레이어, 플래튼 레이어를 사용하였습니다.

# %%
model = Sequential([
    Conv2D(32, (3, 3), padding='same', input_shape=(28, 28, 1), activation='relu'),
    Conv2D(32, (3, 3), padding='same', activation='relu'), 
    Conv2D(32, (3, 3), padding='same', activation='relu'), 
    Conv2D(32, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Conv2D(128, (3, 3), padding='same', activation='relu'), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)),     
    Flatten(), 
    Dense(1024, activation='relu'), 
    Dense(1024, activation='relu'),     
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# 모델 네트워크 아키텍처 구성을 그려보겠습니다.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# 모델을 학습시킬 때, validation_split 옵션을 두면 훈련셋 일부를 검증셋으로 설정할 수 있습니다. 0.2로 설정할 경우, 전체 훈련셋에서 20%를 검증셋, 나머지를 훈련셋으로 구성하여 학습합니다.
#
# 콜백함수를 사용하여, 매 에포크마다 검증셋의 손실값을 체크한 후, 이전 손실값보다 낮은 경우 모델을 파일로 저장합니다. 즉 학습 종료가 되면, "best_model.h5" 파일에 저장된 모델은 손실값이 가장 낮을 때의 가중치를 가지고 있습니다.

# %%
checkpoint_callback = ModelCheckpoint("best_model.h5", 
                                      save_best_only=True, 
                                      monitor="val_loss")

hist = model.fit(x_train, y_train, 
                 validation_split=0.2, 
                 batch_size=32,
                 epochs=100,  
                 callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 34s 16ms/step - loss: 0.3858 - accuracy: 0.8581 - val_loss: 0.2691 - val_accuracy: 0.9002
# Epoch 2/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.2337 - accuracy: 0.9142 - val_loss: 0.2342 - val_accuracy: 0.9122
# Epoch 3/100
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.1882 - accuracy: 0.9295 - val_loss: 0.2436 - val_accuracy: 0.9085
# Epoch 4/100
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.1523 - accuracy: 0.9435 - val_loss: 0.2194 - val_accuracy: 0.9211
# Epoch 5/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.1199 - accuracy: 0.9559 - val_loss: 0.2452 - val_accuracy: 0.9183
# Epoch 6/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0879 - accuracy: 0.9679 - val_loss: 0.2384 - val_accuracy: 0.9249
# Epoch 7/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0662 - accuracy: 0.9752 - val_loss: 0.2655 - val_accuracy: 0.9246
# Epoch 8/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0518 - accuracy: 0.9806 - val_loss: 0.3324 - val_accuracy: 0.9220
# Epoch 9/100
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.0442 - accuracy: 0.9841 - val_loss: 0.3396 - val_accuracy: 0.9271
# Epoch 10/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0360 - accuracy: 0.9870 - val_loss: 0.3782 - val_accuracy: 0.9183
# Epoch 11/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0388 - accuracy: 0.9864 - val_loss: 0.4074 - val_accuracy: 0.9240
# Epoch 12/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 0.4361 - val_accuracy: 0.9179
# Epoch 13/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0282 - accuracy: 0.9911 - val_loss: 0.4933 - val_accuracy: 0.9247
# Epoch 14/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0283 - accuracy: 0.9907 - val_loss: 0.4733 - val_accuracy: 0.9212
# Epoch 15/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0265 - accuracy: 0.9913 - val_loss: 0.5071 - val_accuracy: 0.9250
# Epoch 16/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.5616 - val_accuracy: 0.9238
# Epoch 17/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0250 - accuracy: 0.9920 - val_loss: 0.4897 - val_accuracy: 0.9250
# Epoch 18/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.5490 - val_accuracy: 0.9222
# Epoch 19/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0225 - accuracy: 0.9926 - val_loss: 0.4825 - val_accuracy: 0.9227
# Epoch 20/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0215 - accuracy: 0.9928 - val_loss: 0.6205 - val_accuracy: 0.9203
# Epoch 21/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0202 - accuracy: 0.9938 - val_loss: 0.6009 - val_accuracy: 0.9234
# Epoch 22/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0212 - accuracy: 0.9932 - val_loss: 0.6155 - val_accuracy: 0.9262
# Epoch 23/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0184 - accuracy: 0.9940 - val_loss: 0.6677 - val_accuracy: 0.9208
# Epoch 24/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0245 - accuracy: 0.9928 - val_loss: 0.6663 - val_accuracy: 0.9222
# Epoch 25/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 0.6455 - val_accuracy: 0.9205
# Epoch 26/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0210 - accuracy: 0.9943 - val_loss: 0.6732 - val_accuracy: 0.9237
# Epoch 27/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 0.6862 - val_accuracy: 0.9242
# Epoch 28/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0199 - accuracy: 0.9942 - val_loss: 0.6527 - val_accuracy: 0.9228
# Epoch 29/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0221 - accuracy: 0.9942 - val_loss: 0.5788 - val_accuracy: 0.9214
# Epoch 30/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0160 - accuracy: 0.9952 - val_loss: 0.7660 - val_accuracy: 0.9195
# Epoch 31/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0168 - accuracy: 0.9947 - val_loss: 0.7726 - val_accuracy: 0.9208
# Epoch 32/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0206 - accuracy: 0.9944 - val_loss: 0.8928 - val_accuracy: 0.9262
# Epoch 33/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 0.6674 - val_accuracy: 0.9263
# Epoch 34/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0169 - accuracy: 0.9955 - val_loss: 0.7474 - val_accuracy: 0.9247
# Epoch 35/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0172 - accuracy: 0.9954 - val_loss: 0.7452 - val_accuracy: 0.9208
# Epoch 36/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0175 - accuracy: 0.9959 - val_loss: 0.7966 - val_accuracy: 0.9204
# Epoch 37/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.8806 - val_accuracy: 0.9231
# Epoch 38/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0177 - accuracy: 0.9953 - val_loss: 0.7802 - val_accuracy: 0.9201
# Epoch 39/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0193 - accuracy: 0.9955 - val_loss: 0.8229 - val_accuracy: 0.9227
# Epoch 40/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.9643 - val_accuracy: 0.9183
# Epoch 41/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0210 - accuracy: 0.9948 - val_loss: 0.8629 - val_accuracy: 0.9229
# Epoch 42/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0169 - accuracy: 0.9960 - val_loss: 0.9311 - val_accuracy: 0.9236
# Epoch 43/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0172 - accuracy: 0.9959 - val_loss: 0.8916 - val_accuracy: 0.9242
# Epoch 44/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0137 - accuracy: 0.9965 - val_loss: 0.8722 - val_accuracy: 0.9255
# Epoch 45/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0189 - accuracy: 0.9953 - val_loss: 0.8930 - val_accuracy: 0.9237
# Epoch 46/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0189 - accuracy: 0.9956 - val_loss: 0.8747 - val_accuracy: 0.9239
# Epoch 47/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0141 - accuracy: 0.9966 - val_loss: 0.9157 - val_accuracy: 0.9202
# Epoch 48/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0173 - accuracy: 0.9959 - val_loss: 0.8890 - val_accuracy: 0.9262
# Epoch 49/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0148 - accuracy: 0.9965 - val_loss: 1.0124 - val_accuracy: 0.9232
# Epoch 50/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0211 - accuracy: 0.9956 - val_loss: 0.8311 - val_accuracy: 0.9248
# Epoch 51/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0102 - accuracy: 0.9976 - val_loss: 0.9208 - val_accuracy: 0.9257
# Epoch 52/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0193 - accuracy: 0.9955 - val_loss: 0.9399 - val_accuracy: 0.9245
# Epoch 53/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0165 - accuracy: 0.9963 - val_loss: 1.1737 - val_accuracy: 0.9172
# Epoch 54/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0188 - accuracy: 0.9959 - val_loss: 1.1482 - val_accuracy: 0.9227
# Epoch 55/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0147 - accuracy: 0.9965 - val_loss: 1.0934 - val_accuracy: 0.9247
# Epoch 56/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0152 - accuracy: 0.9967 - val_loss: 0.9781 - val_accuracy: 0.9259
# Epoch 57/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0204 - accuracy: 0.9958 - val_loss: 1.1056 - val_accuracy: 0.9202
# Epoch 58/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0198 - accuracy: 0.9960 - val_loss: 1.2978 - val_accuracy: 0.9198
# Epoch 59/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0167 - accuracy: 0.9965 - val_loss: 1.1230 - val_accuracy: 0.9212
# Epoch 60/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0178 - accuracy: 0.9962 - val_loss: 1.1684 - val_accuracy: 0.9241
# Epoch 61/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0206 - accuracy: 0.9963 - val_loss: 1.2655 - val_accuracy: 0.9190
# Epoch 62/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0180 - accuracy: 0.9961 - val_loss: 1.2678 - val_accuracy: 0.9218
# Epoch 63/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0147 - accuracy: 0.9971 - val_loss: 1.2006 - val_accuracy: 0.9249
# Epoch 64/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0122 - accuracy: 0.9974 - val_loss: 1.3777 - val_accuracy: 0.9195
# Epoch 65/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0167 - accuracy: 0.9966 - val_loss: 1.4067 - val_accuracy: 0.9233
# Epoch 66/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0180 - accuracy: 0.9965 - val_loss: 1.4820 - val_accuracy: 0.9171
# Epoch 67/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0176 - accuracy: 0.9971 - val_loss: 1.3612 - val_accuracy: 0.9229
# Epoch 68/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0152 - accuracy: 0.9970 - val_loss: 1.3770 - val_accuracy: 0.9208
# Epoch 69/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0146 - accuracy: 0.9970 - val_loss: 1.5204 - val_accuracy: 0.9218
# Epoch 70/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0237 - accuracy: 0.9959 - val_loss: 1.4716 - val_accuracy: 0.9205
# Epoch 71/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 1.6679 - val_accuracy: 0.9223
# Epoch 72/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0182 - accuracy: 0.9971 - val_loss: 1.4853 - val_accuracy: 0.9228
# Epoch 73/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0141 - accuracy: 0.9974 - val_loss: 1.3967 - val_accuracy: 0.9239
# Epoch 74/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0148 - accuracy: 0.9973 - val_loss: 1.3831 - val_accuracy: 0.9228
# Epoch 75/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0190 - accuracy: 0.9967 - val_loss: 1.4789 - val_accuracy: 0.9233
# Epoch 76/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0233 - accuracy: 0.9960 - val_loss: 1.5102 - val_accuracy: 0.9227
# Epoch 77/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0147 - accuracy: 0.9972 - val_loss: 1.4211 - val_accuracy: 0.9232
# Epoch 78/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0164 - accuracy: 0.9970 - val_loss: 1.7080 - val_accuracy: 0.9170
# Epoch 79/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0193 - accuracy: 0.9967 - val_loss: 1.5256 - val_accuracy: 0.9153
# Epoch 80/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0204 - accuracy: 0.9965 - val_loss: 1.3400 - val_accuracy: 0.9238
# Epoch 81/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0141 - accuracy: 0.9972 - val_loss: 1.8286 - val_accuracy: 0.9198
# Epoch 82/100
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0214 - accuracy: 0.9966 - val_loss: 1.4830 - val_accuracy: 0.9273
# Epoch 83/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0124 - accuracy: 0.9979 - val_loss: 1.6081 - val_accuracy: 0.9240
# Epoch 84/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0157 - accuracy: 0.9975 - val_loss: 1.6068 - val_accuracy: 0.9213
# Epoch 85/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0163 - accuracy: 0.9974 - val_loss: 1.5780 - val_accuracy: 0.9243
# Epoch 86/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0164 - accuracy: 0.9971 - val_loss: 1.8272 - val_accuracy: 0.9208
# Epoch 87/100
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0277 - accuracy: 0.9962 - val_loss: 1.8049 - val_accuracy: 0.9276
# Epoch 88/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0157 - accuracy: 0.9975 - val_loss: 1.8704 - val_accuracy: 0.9266
# Epoch 89/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0235 - accuracy: 0.9966 - val_loss: 1.4133 - val_accuracy: 0.9240
# Epoch 90/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0128 - accuracy: 0.9981 - val_loss: 1.9587 - val_accuracy: 0.9262
# Epoch 91/100
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0177 - accuracy: 0.9974 - val_loss: 1.8732 - val_accuracy: 0.9246
# Epoch 92/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0233 - accuracy: 0.9969 - val_loss: 1.6131 - val_accuracy: 0.9218
# Epoch 93/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0190 - accuracy: 0.9976 - val_loss: 1.6067 - val_accuracy: 0.9260
# Epoch 94/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0158 - accuracy: 0.9975 - val_loss: 1.8318 - val_accuracy: 0.9237
# Epoch 95/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0177 - accuracy: 0.9976 - val_loss: 1.9336 - val_accuracy: 0.9225
# Epoch 96/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0221 - accuracy: 0.9968 - val_loss: 1.8387 - val_accuracy: 0.9261
# Epoch 97/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0136 - accuracy: 0.9980 - val_loss: 1.8840 - val_accuracy: 0.9267
# Epoch 98/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0217 - accuracy: 0.9973 - val_loss: 2.1413 - val_accuracy: 0.9204
# Epoch 99/100
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0252 - accuracy: 0.9968 - val_loss: 2.1560 - val_accuracy: 0.9179
# Epoch 100/100
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0159 - accuracy: 0.9978 - val_loss: 2.2032 - val_accuracy: 0.9228

# %% [markdown]
# 학습 시 매 에포크에 해당하는 훈련셋과 검증셋에 대한 손실값과 평가 메트릭 수치를 확인할 수 있습니다. 이를 시각화시키면 어느 에포크에서 오버피팅이 일어났는 지 한 눈에 확인할 수 있습니다.

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# 파일로 저장된 모델을 로딩하여 시험셋으로 최종 평가를 수행합니다.

# %%
model = load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2390 - accuracy: 0.9160
# Test accuracy 0.9160000085830688
# Test loss 0.23899221420288086

# %% [markdown]
# 또한 시험셋으로 테스트한 결과를 제출하기 위해 모델 결과 파일을 저장합니다. 출력이 10개 클래스에 해당하는 벡터이므로, 분류한 클래스 정보를 얻기 위해 가장 높은 값을 가진 인덱스 값을 가지고 옵니다. 이 인덱스가 클래스를 의미하며, 이 값을 파일로 저장합니다.

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.argmax(axis=-1)
np.savetxt('y_pred.csv', y_pred, fmt='%d')

# %% [markdown]
# #### 실제로 사용해보기

# %%
def download_real_image(filename):
    url = 'https://github.com/aifactory-team/AFClass/blob/master/aifactory/warehouse/' + filename + '?raw=true' 
    urllib.request.urlretrieve(url, filename)

def predict_from_real_image(filename, invert):
    
    f, axarr = plt.subplots(2,2, subplot_kw={'xticks': [], 'yticks': []})
    
    img = Image.open(filename)
    axarr[0,0].imshow(img)
    axarr[0,0].set_title('orgin')

    img = img.resize((28, 28), Image.LANCZOS)
    axarr[0,1].imshow(img)
    axarr[0,1].set_title('resize')

    img = img.convert('L')
    axarr[1,0].imshow(img, cmap='gray')
    axarr[1,0].set_title('gray')

    img = np.array(img)
    if invert == True:
        img = 255.0 - img
        axarr[1,1].set_title('invert')
    else:
        axarr[1,1].set_title('no invert')
        
    axarr[1,1].imshow(img, cmap='gray')

    x_predict = img.reshape(1, 28, 28, 1).astype('float32') / 255.0
    y_predict = model.predict(x_predict)
    print(y_predict)
    print(labels[np.argmax(y_predict, axis=1)[0]])

# %%
download_real_image('fashion_item_1.png')
predict_from_real_image('fashion_item_1.png', invert = True)
# Out:
# [[7.7969272e-04 2.0238197e-06 3.4775483e-04 2.2840351e-05 1.7623190e-03
#   6.9423031e-06 1.2237333e-04 3.0407946e-06 9.9690944e-01 4.3577420e-05]]
# Bag

# %%
download_real_image('fashion_item_2.png')
predict_from_real_image('fashion_item_2.png', invert=False)
# Out:
# [[9.13116673e-05 1.21236114e-08 1.38475485e-07 1.60307234e-08
#   9.15595211e-10 9.15858180e-08 8.67898962e-06 1.24681662e-06
#   9.99897361e-01 1.05553806e-06]]
# Bag

# %%
download_real_image('fashion_item_2.png')
predict_from_real_image('fashion_item_2.png', invert=True)
# Out:
# [[1.8476084e-03 7.0554470e-06 5.8049182e-03 9.3958341e-02 8.9769542e-01
#   7.4375077e-07 2.3602901e-04 2.6375546e-06 4.4426788e-04 3.0944666e-06]]
# Coat

# %%
download_real_image('fashion_item_3.png')
predict_from_real_image('fashion_item_3.png', invert=True)
# Out:
# [[2.4221526e-01 4.7710523e-04 7.6382392e-04 8.7703943e-02 5.1469854e-03
#   3.1545004e-03 2.8277975e-02 7.1099461e-03 6.2469333e-01 4.5717813e-04]]
# Bag

# %%
download_real_image('fashion_item_4.png')
predict_from_real_image('fashion_item_4.png', invert=True)
# Out:
# [[3.6949019e-05 3.5899566e-06 9.8509145e-06 9.7115684e-05 1.2492689e-05
#   9.1902140e-05 1.0899207e-05 9.8717427e-01 9.4689622e-06 1.2553499e-02]]
# Sneaker

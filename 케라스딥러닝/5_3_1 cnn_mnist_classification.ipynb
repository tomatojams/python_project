# %% [markdown]
# 필요한 패키지를 가져옵니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import mnist

# %% [markdown]
# 이미지 데이터셋을 불러옵니다.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print('x_train shape : ' + str(x_train.shape))
print('y_train shape : ' + str(y_train.shape))
print('x_test shape : ' + str(x_test.shape))
print('y_test shape : ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train shape : (60000, 28, 28)
# y_train shape : (60000,)
# x_test shape : (10000, 28, 28)
# y_test shape : (10000,)

# %% [markdown]
# 테스트할 샘플 하나를 살펴봅니다.

# %%
import matplotlib.pyplot as plt

plt.imshow(x_test[0], cmap='gray')

# %% [markdown]
# 인공지능 모델이 이 이미지를 입력받았을 때, 해당하는 숫자를 출력할 수 있도록 만드는 것이 목표입니다. 우리는 y_test 라벨값도 가지고 있어서 바로 확인은 할 수 있으나, 모델 학습 시에는 사용이 되지 않으며, 시험 평가할 때만 사용됩니다.

# %%
print(y_test[0])
# Out:
# 7

# %% [markdown]
# 이미지와 라벨과 함께 같이 가시화 시킵니다.

# %%
fig, axes = plt.subplots(nrows=10, ncols=10, figsize=(13, 15), 
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap = 'gray')
    title = str(y_train[i])
    ax.set_title(title)

plt.show()

# %% [markdown]
# 모델 학습에 용이하도록 다음과 같이 데이터 전처리를 수행합니다.
#
# *   데이터 전처리
#     * 3차원(샘플수, 세로, 가로)를 4차원(샘플수, 세로, 가로, 채널)으로 변경
#     * 정수를 실수로 변경
#     * 0 ~ 255 사이의 수치를 0.0 ~ 1.0 사이로 정규화 수행
# *   라벨 전처리
#     * 0 ~ 9 라벨에 대한 원핫인코딩 수행

# %%
x_train = x_train.reshape(60000, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(10000, 28, 28, 1).astype('float32') / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# 모델은 다음과 같이 구성하였습니다.
#
# * 입력: 3차원 벡터 (세로 28, 가로 28, 채널 1)
# * 출력: 10개 벡터
# * 출력층의 활성화 함수: 소프트맥스
# * 손실함수: categorical_crossentropy
# * 최적화기: adam
# * 평가 메트릭: accuracy
#
# 컨볼루션 신경망을 구성하기 위해, 컨볼루션 레이어, 맥스풀링 레이어, 플래튼 레이어를 사용하였습니다.

# %%
model = Sequential([
    Conv2D(32, (3, 3), padding='same', input_shape=(28, 28, 1), activation='relu'),
    Conv2D(32, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Flatten(), 
    Dense(512, activation='relu'), 
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# 모델 네트워크 아키텍처 구성을 그려보겠습니다.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# 모델을 학습시킬 때, validation_split 옵션을 두면 훈련셋 일부를 검증셋으로 설정할 수 있습니다. 0.2로 설정할 경우, 전체 훈련셋에서 20%를 검증셋, 나머지를 훈련셋으로 구성하여 학습합니다.
#
# 콜백함수를 사용하여, 매 에포크마다 검증셋의 손실값을 체크한 후, 이전 손실값보다 낮은 경우 모델을 파일로 저장합니다. 즉 학습 종료가 되면, "best_model.h5" 파일에 저장된 모델은 손실값이 가장 낮을 때의 가중치를 가지고 있습니다.

# %%
checkpoint_callback = ModelCheckpoint("best_model.h5", 
                                      save_best_only=True, 
                                      monitor="val_loss")

hist = model.fit(x_train, y_train, 
                 validation_split=0.2, 
                 batch_size=32,
                 epochs=100,  
                 callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 34s 16ms/step - loss: 0.1143 - accuracy: 0.9639 - val_loss: 0.0499 - val_accuracy: 0.9864
# Epoch 2/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0385 - accuracy: 0.9874 - val_loss: 0.0382 - val_accuracy: 0.9889
# Epoch 3/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 0.0351 - val_accuracy: 0.9898
# Epoch 4/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0189 - accuracy: 0.9936 - val_loss: 0.0336 - val_accuracy: 0.9912
# Epoch 5/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 0.0380 - val_accuracy: 0.9895
# Epoch 6/100
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.0345 - val_accuracy: 0.9913
# Epoch 7/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 0.0374 - val_accuracy: 0.9929
# Epoch 8/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0435 - val_accuracy: 0.9902
# Epoch 9/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0402 - val_accuracy: 0.9924
# Epoch 10/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0655 - val_accuracy: 0.9894
# Epoch 11/100
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0430 - val_accuracy: 0.9911
# Epoch 12/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0492 - val_accuracy: 0.9907
# Epoch 13/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0563 - val_accuracy: 0.9873
# Epoch 14/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0461 - val_accuracy: 0.9918
# Epoch 15/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0629 - val_accuracy: 0.9908
# Epoch 16/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0628 - val_accuracy: 0.9896
# Epoch 17/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0541 - val_accuracy: 0.9911
# Epoch 18/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0449 - val_accuracy: 0.9918
# Epoch 19/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0433 - val_accuracy: 0.9923
# Epoch 20/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0588 - val_accuracy: 0.9915
# Epoch 21/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0533 - val_accuracy: 0.9920
# Epoch 22/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0731 - val_accuracy: 0.9894
# Epoch 23/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0540 - val_accuracy: 0.9928
# Epoch 24/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.0671 - val_accuracy: 0.9909
# Epoch 25/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0810 - val_accuracy: 0.9912
# Epoch 26/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.0673 - val_accuracy: 0.9912
# Epoch 27/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0833 - val_accuracy: 0.9916
# Epoch 28/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0062 - accuracy: 0.9988 - val_loss: 0.0809 - val_accuracy: 0.9914
# Epoch 29/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0843 - val_accuracy: 0.9919
# Epoch 30/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.0689 - val_accuracy: 0.9907
# Epoch 31/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0635 - val_accuracy: 0.9933
# Epoch 32/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.1845 - val_accuracy: 0.9847
# Epoch 33/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0070 - accuracy: 0.9985 - val_loss: 0.0734 - val_accuracy: 0.9922
# Epoch 34/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.1144 - val_accuracy: 0.9910
# Epoch 35/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.1130 - val_accuracy: 0.9899
# Epoch 36/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 0.1186 - val_accuracy: 0.9906
# Epoch 37/100
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0842 - val_accuracy: 0.9923
# Epoch 38/100
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0068 - accuracy: 0.9991 - val_loss: 0.1602 - val_accuracy: 0.9899
# Epoch 39/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0057 - accuracy: 0.9992 - val_loss: 0.1086 - val_accuracy: 0.9909
# Epoch 40/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.1360 - val_accuracy: 0.9904
# Epoch 41/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.1242 - val_accuracy: 0.9900
# Epoch 42/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.1054 - val_accuracy: 0.9918
# Epoch 43/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.1486 - val_accuracy: 0.9885
# Epoch 44/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0066 - accuracy: 0.9988 - val_loss: 0.0870 - val_accuracy: 0.9919
# Epoch 45/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.1317 - val_accuracy: 0.9908
# Epoch 46/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.1139 - val_accuracy: 0.9913
# Epoch 47/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0057 - accuracy: 0.9989 - val_loss: 0.1268 - val_accuracy: 0.9915
# Epoch 48/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0056 - accuracy: 0.9991 - val_loss: 0.1253 - val_accuracy: 0.9921
# Epoch 49/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0047 - accuracy: 0.9992 - val_loss: 0.1430 - val_accuracy: 0.9909
# Epoch 50/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.1425 - val_accuracy: 0.9923
# Epoch 51/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.1365 - val_accuracy: 0.9909
# Epoch 52/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.1303 - val_accuracy: 0.9922
# Epoch 53/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.1899 - val_accuracy: 0.9897
# Epoch 54/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0061 - accuracy: 0.9993 - val_loss: 0.1555 - val_accuracy: 0.9922
# Epoch 55/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.1416 - val_accuracy: 0.9918
# Epoch 56/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0066 - accuracy: 0.9990 - val_loss: 0.1913 - val_accuracy: 0.9910
# Epoch 57/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0057 - accuracy: 0.9995 - val_loss: 0.1727 - val_accuracy: 0.9923
# Epoch 58/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0047 - accuracy: 0.9993 - val_loss: 0.1701 - val_accuracy: 0.9920
# Epoch 59/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.1439 - val_accuracy: 0.9919
# Epoch 60/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.1912 - val_accuracy: 0.9920
# Epoch 61/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 0.1780 - val_accuracy: 0.9915
# Epoch 62/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.1560 - val_accuracy: 0.9925
# Epoch 63/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.2221 - val_accuracy: 0.9898
# Epoch 64/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 0.2070 - val_accuracy: 0.9905
# Epoch 65/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.2482 - val_accuracy: 0.9901
# Epoch 66/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0057 - accuracy: 0.9994 - val_loss: 0.2012 - val_accuracy: 0.9924
# Epoch 67/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1948 - val_accuracy: 0.9924
# Epoch 68/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0055 - accuracy: 0.9994 - val_loss: 0.2342 - val_accuracy: 0.9918
# Epoch 69/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0117 - accuracy: 0.9991 - val_loss: 0.3032 - val_accuracy: 0.9906
# Epoch 70/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.2612 - val_accuracy: 0.9912
# Epoch 71/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0043 - accuracy: 0.9996 - val_loss: 0.2194 - val_accuracy: 0.9906
# Epoch 72/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0054 - accuracy: 0.9994 - val_loss: 0.2069 - val_accuracy: 0.9907
# Epoch 73/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0080 - accuracy: 0.9993 - val_loss: 0.1926 - val_accuracy: 0.9909
# Epoch 74/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0042 - accuracy: 0.9996 - val_loss: 0.1853 - val_accuracy: 0.9918
# Epoch 75/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 0.2050 - val_accuracy: 0.9912
# Epoch 76/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.2629 - val_accuracy: 0.9902
# Epoch 77/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0066 - accuracy: 0.9994 - val_loss: 0.2551 - val_accuracy: 0.9917
# Epoch 78/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.2641 - val_accuracy: 0.9906
# Epoch 79/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0066 - accuracy: 0.9994 - val_loss: 0.2677 - val_accuracy: 0.9916
# Epoch 80/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0063 - accuracy: 0.9993 - val_loss: 0.2270 - val_accuracy: 0.9916
# Epoch 81/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.2216 - val_accuracy: 0.9931
# Epoch 82/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0072 - accuracy: 0.9995 - val_loss: 0.2534 - val_accuracy: 0.9907
# Epoch 83/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0039 - accuracy: 0.9996 - val_loss: 0.2554 - val_accuracy: 0.9913
# Epoch 84/100
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0048 - accuracy: 0.9995 - val_loss: 0.2271 - val_accuracy: 0.9923
# Epoch 85/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.3025 - val_accuracy: 0.9909
# Epoch 86/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0084 - accuracy: 0.9994 - val_loss: 0.3877 - val_accuracy: 0.9916
# Epoch 87/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0072 - accuracy: 0.9995 - val_loss: 0.3693 - val_accuracy: 0.9898
# Epoch 88/100
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.0097 - accuracy: 0.9994 - val_loss: 0.3010 - val_accuracy: 0.9918
# Epoch 89/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.3323 - val_accuracy: 0.9912
# Epoch 90/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0046 - accuracy: 0.9996 - val_loss: 0.2549 - val_accuracy: 0.9919
# Epoch 91/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0113 - accuracy: 0.9994 - val_loss: 0.2599 - val_accuracy: 0.9921
# Epoch 92/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0043 - accuracy: 0.9997 - val_loss: 0.2726 - val_accuracy: 0.9923
# Epoch 93/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.3232 - val_accuracy: 0.9913
# Epoch 94/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0090 - accuracy: 0.9993 - val_loss: 0.2843 - val_accuracy: 0.9930
# Epoch 95/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 0.3682 - val_accuracy: 0.9919
# Epoch 96/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0133 - accuracy: 0.9994 - val_loss: 0.3383 - val_accuracy: 0.9908
# Epoch 97/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.4030 - val_accuracy: 0.9904
# Epoch 98/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.4330 - val_accuracy: 0.9914
# Epoch 99/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0062 - accuracy: 0.9996 - val_loss: 0.5982 - val_accuracy: 0.9908
# Epoch 100/100
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0097 - accuracy: 0.9995 - val_loss: 0.4487 - val_accuracy: 0.9913

# %% [markdown]
# 학습 시 매 에포크에 해당하는 훈련셋과 검증셋에 대한 손실값과 평가 메트릭 수치를 확인할 수 있습니다. 이를 시각화시키면 어느 에포크에서 오버피팅이 일어났는 지 한 눈에 확인할 수 있습니다.

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# 파일로 저장된 모델을 로딩하여 시험셋으로 최종 평가를 수행합니다.

# %%
model = load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0270 - accuracy: 0.9912
# Test accuracy 0.9911999702453613
# Test loss 0.026951931416988373

# %% [markdown]
# # 패키지 불러오기

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.4.1)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)

# %%
import tensorflow as tf
import numpy as np
import os
import json

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

from preprocess import *

# %% [markdown]
# # 시각화 함수

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string], '')
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %% [markdown]
# # 학습 데이터 경로 정의

# %%
DATA_IN_PATH = './'
DATA_OUT_PATH = './'
TRAIN_INPUTS = 'train_inputs.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIGS = 'data_configs.json'

# %% [markdown]
# # 랜덤 시드 고정

# %%
SEED_NUM = 1234
tf.random.set_seed(SEED_NUM)

# %% [markdown]
# # 파일 로드

# %%
index_inputs = np.load(open(DATA_IN_PATH + TRAIN_INPUTS, 'rb'))
index_outputs = np.load(open(DATA_IN_PATH + TRAIN_OUTPUTS , 'rb'))
index_targets = np.load(open(DATA_IN_PATH + TRAIN_TARGETS , 'rb'))
prepro_configs = json.load(open(DATA_IN_PATH + DATA_CONFIGS, 'r'))

# %%
# Show length
print(len(index_inputs),  len(index_outputs), len(index_targets))
# Out:
# 20 20 20

# %% [markdown]
# ## 모델 만들기에 필요한 값 선언

# %%
MODEL_NAME = 'seq2seq_kor'
BATCH_SIZE = 2
MAX_SEQUENCE = 25
EPOCH = 30
UNITS = 1024
EMBEDDING_DIM = 256
VALIDATION_SPLIT = 0.1 

char2idx = prepro_configs['char2idx']
idx2char = prepro_configs['idx2char']
std_index = prepro_configs['std_symbol']
end_index = prepro_configs['end_symbol']
vocab_size = prepro_configs['vocab_size']

# %% [markdown]
# # 모델

# %% [markdown]
# ## 인코더

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.vocab_size = vocab_size 
        self.embedding_dim = embedding_dim          
        
        self.embedding = tf.keras.layers.Embedding(self.vocab_size, self.embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        return output, state

    def initialize_hidden_state(self, inp):
        return tf.zeros((tf.shape(inp)[0], self.enc_units))

# %% [markdown]
# ## 어텐션

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
        hidden_with_time_axis = tf.expand_dims(query, 1)

        score = self.V(tf.nn.tanh(
            self.W1(values) + self.W2(hidden_with_time_axis)))

        attention_weights = tf.nn.softmax(score, axis=1)

        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %% [markdown]
# ## 디코더

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.vocab_size = vocab_size 
        self.embedding_dim = embedding_dim  
        
        self.embedding = tf.keras.layers.Embedding(self.vocab_size, self.embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(self.vocab_size)

        self.attention = BahdanauAttention(self.dec_units)
        
    def call(self, x, hidden, enc_output):
        context_vector, attention_weights = self.attention(hidden, enc_output)

        x = self.embedding(x)

        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        output, state = self.gru(x)
        output = tf.reshape(output, (-1, output.shape[2]))
            
        x = self.fc(output)
        
        return x, state, attention_weights

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')

def loss(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

def accuracy(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    mask = tf.expand_dims(tf.cast(mask, dtype=pred.dtype), axis=-1)
    pred *= mask    
    acc = train_accuracy(real, pred)

    return tf.reduce_mean(acc)

# %% [markdown]
# ## 시퀀스 투 스퀀스 모델

# %%
class seq2seq(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, dec_units, batch_sz, end_token_idx=2):    
        super(seq2seq, self).__init__()
        self.end_token_idx = end_token_idx
        self.encoder = Encoder(vocab_size, embedding_dim, enc_units, batch_sz) 
        self.decoder = Decoder(vocab_size, embedding_dim, dec_units, batch_sz) 

    def call(self, x):
        inp, tar = x
        
        enc_hidden = self.encoder.initialize_hidden_state(inp)
        enc_output, enc_hidden = self.encoder(inp, enc_hidden)

        dec_hidden = enc_hidden

        predict_tokens = list()
        for t in range(0, tar.shape[1]):
            dec_input = tf.dtypes.cast(tf.expand_dims(tar[:, t], 1), tf.float32) 
            predictions, dec_hidden, _ = self.decoder(dec_input, dec_hidden, enc_output)
            predict_tokens.append(tf.dtypes.cast(predictions, tf.float32))   
        return tf.stack(predict_tokens, axis=1)
    
    def inference(self, x):
        inp  = x

        enc_hidden = self.encoder.initialize_hidden_state(inp)
        enc_output, enc_hidden = self.encoder(inp, enc_hidden)

        dec_hidden = enc_hidden
        
        dec_input = tf.expand_dims([char2idx[std_index]], 1)
        
        predict_tokens = list()
        for t in range(0, MAX_SEQUENCE):
            predictions, dec_hidden, _ = self.decoder(dec_input, dec_hidden, enc_output)
            predict_token = tf.argmax(predictions[0])
            
            if predict_token == self.end_token_idx:
                break
            
            predict_tokens.append(predict_token)
            dec_input = tf.dtypes.cast(tf.expand_dims([predict_token], 0), tf.float32)   
            
        return tf.stack(predict_tokens, axis=0).numpy()

# %%
model = seq2seq(vocab_size, EMBEDDING_DIM, UNITS, UNITS, BATCH_SIZE, char2idx[end_index])
model.compile(loss=loss, optimizer=tf.keras.optimizers.Adam(1e-3), metrics=[accuracy])

# %% [markdown]
# ## 학습 진행

# %%
PATH = DATA_OUT_PATH + MODEL_NAME
if not(os.path.isdir(PATH)):
        os.makedirs(os.path.join(PATH))
        
checkpoint_path = DATA_OUT_PATH + MODEL_NAME + '/weights.h5'
    
cp_callback = ModelCheckpoint(
    checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True)

earlystop_callback = EarlyStopping(monitor='val_accuracy', min_delta=0.0001, patience=10)

history = model.fit([index_inputs, index_outputs], index_targets,
                    batch_size=BATCH_SIZE, epochs=EPOCH,
                    validation_split=VALIDATION_SPLIT, callbacks=[earlystop_callback, cp_callback])
# Out:
# Epoch 1/30
# 9/9 [==============================] - ETA: 0s - loss: 0.9256 - accuracy: 0.8360
# Epoch 1: val_accuracy improved from -inf to 0.85400, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 57s 1s/step - loss: 0.9256 - accuracy: 0.8360 - val_loss: 0.7037 - val_accuracy: 0.8540
# Epoch 2/30
# 9/9 [==============================] - ETA: 0s - loss: 0.7913 - accuracy: 0.8527
# Epoch 2: val_accuracy improved from 0.85400 to 0.85600, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 160ms/step - loss: 0.7913 - accuracy: 0.8527 - val_loss: 0.6026 - val_accuracy: 0.8560
# Epoch 3/30
# 9/9 [==============================] - ETA: 0s - loss: 0.6794 - accuracy: 0.8572
# Epoch 3: val_accuracy improved from 0.85600 to 0.85667, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 126ms/step - loss: 0.6794 - accuracy: 0.8572 - val_loss: 0.5561 - val_accuracy: 0.8567
# Epoch 4/30
# 9/9 [==============================] - ETA: 0s - loss: 0.6282 - accuracy: 0.8572
# Epoch 4: val_accuracy improved from 0.85667 to 0.85700, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 106ms/step - loss: 0.6282 - accuracy: 0.8572 - val_loss: 0.5486 - val_accuracy: 0.8570
# Epoch 5/30
# 9/9 [==============================] - ETA: 0s - loss: 0.5857 - accuracy: 0.8573
# Epoch 5: val_accuracy improved from 0.85700 to 0.85720, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 115ms/step - loss: 0.5857 - accuracy: 0.8573 - val_loss: 0.5080 - val_accuracy: 0.8572
# Epoch 6/30
# 9/9 [==============================] - ETA: 0s - loss: 0.5374 - accuracy: 0.8570
# Epoch 6: val_accuracy improved from 0.85720 to 0.85800, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 113ms/step - loss: 0.5374 - accuracy: 0.8570 - val_loss: 0.4569 - val_accuracy: 0.8580
# Epoch 7/30
# 9/9 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.8586
# Epoch 7: val_accuracy improved from 0.85800 to 0.85943, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 140ms/step - loss: 0.4850 - accuracy: 0.8586 - val_loss: 0.4224 - val_accuracy: 0.8594
# Epoch 8/30
# 9/9 [==============================] - ETA: 0s - loss: 0.4345 - accuracy: 0.8613
# Epoch 8: val_accuracy improved from 0.85943 to 0.86250, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 110ms/step - loss: 0.4345 - accuracy: 0.8613 - val_loss: 0.3836 - val_accuracy: 0.8625
# Epoch 9/30
# 9/9 [==============================] - ETA: 0s - loss: 0.3783 - accuracy: 0.8644
# Epoch 9: val_accuracy improved from 0.86250 to 0.86667, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 105ms/step - loss: 0.3783 - accuracy: 0.8644 - val_loss: 0.3450 - val_accuracy: 0.8667
# Epoch 10/30
# 9/9 [==============================] - ETA: 0s - loss: 0.3335 - accuracy: 0.8696
# Epoch 10: val_accuracy improved from 0.86667 to 0.87320, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 106ms/step - loss: 0.3335 - accuracy: 0.8696 - val_loss: 0.2857 - val_accuracy: 0.8732
# Epoch 11/30
# 9/9 [==============================] - ETA: 0s - loss: 0.2899 - accuracy: 0.8769
# Epoch 11: val_accuracy improved from 0.87320 to 0.88018, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 105ms/step - loss: 0.2899 - accuracy: 0.8769 - val_loss: 0.2433 - val_accuracy: 0.8802
# Epoch 12/30
# 9/9 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.8836
# Epoch 12: val_accuracy improved from 0.88018 to 0.88667, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 105ms/step - loss: 0.2331 - accuracy: 0.8836 - val_loss: 0.2089 - val_accuracy: 0.8867
# Epoch 13/30
# 9/9 [==============================] - ETA: 0s - loss: 0.2029 - accuracy: 0.8894
# Epoch 13: val_accuracy improved from 0.88667 to 0.89200, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 110ms/step - loss: 0.2029 - accuracy: 0.8894 - val_loss: 0.2234 - val_accuracy: 0.8920
# Epoch 14/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.8946
# Epoch 14: val_accuracy improved from 0.89200 to 0.89671, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 104ms/step - loss: 0.1845 - accuracy: 0.8946 - val_loss: 0.1231 - val_accuracy: 0.8967
# Epoch 15/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.8988
# Epoch 15: val_accuracy improved from 0.89671 to 0.90067, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 104ms/step - loss: 0.1585 - accuracy: 0.8988 - val_loss: 0.1545 - val_accuracy: 0.9007
# Epoch 16/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9026
# Epoch 16: val_accuracy improved from 0.90067 to 0.90438, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 108ms/step - loss: 0.1441 - accuracy: 0.9026 - val_loss: 0.1154 - val_accuracy: 0.9044
# Epoch 17/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9060
# Epoch 17: val_accuracy improved from 0.90438 to 0.90753, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 105ms/step - loss: 0.1329 - accuracy: 0.9060 - val_loss: 0.1243 - val_accuracy: 0.9075
# Epoch 18/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9090
# Epoch 18: val_accuracy improved from 0.90753 to 0.91033, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 119ms/step - loss: 0.1288 - accuracy: 0.9090 - val_loss: 0.1237 - val_accuracy: 0.9103
# Epoch 19/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9115
# Epoch 19: val_accuracy improved from 0.91033 to 0.91253, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 114ms/step - loss: 0.1235 - accuracy: 0.9115 - val_loss: 0.1264 - val_accuracy: 0.9125
# Epoch 20/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9138
# Epoch 20: val_accuracy improved from 0.91253 to 0.91490, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 107ms/step - loss: 0.1199 - accuracy: 0.9138 - val_loss: 0.1154 - val_accuracy: 0.9149
# Epoch 21/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9158
# Epoch 21: val_accuracy improved from 0.91490 to 0.91686, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 111ms/step - loss: 0.1172 - accuracy: 0.9158 - val_loss: 0.1230 - val_accuracy: 0.9169
# Epoch 22/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9179
# Epoch 22: val_accuracy improved from 0.91686 to 0.91882, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 108ms/step - loss: 0.1135 - accuracy: 0.9179 - val_loss: 0.1169 - val_accuracy: 0.9188
# Epoch 23/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.9198
# Epoch 23: val_accuracy improved from 0.91882 to 0.92087, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 107ms/step - loss: 0.1002 - accuracy: 0.9198 - val_loss: 0.1208 - val_accuracy: 0.9209
# Epoch 24/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9219
# Epoch 24: val_accuracy improved from 0.92087 to 0.92267, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 109ms/step - loss: 0.1050 - accuracy: 0.9219 - val_loss: 0.1182 - val_accuracy: 0.9227
# Epoch 25/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9237
# Epoch 25: val_accuracy improved from 0.92267 to 0.92464, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 106ms/step - loss: 0.0836 - accuracy: 0.9237 - val_loss: 0.1096 - val_accuracy: 0.9246
# Epoch 26/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9257
# Epoch 26: val_accuracy improved from 0.92464 to 0.92662, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 107ms/step - loss: 0.0693 - accuracy: 0.9257 - val_loss: 0.1400 - val_accuracy: 0.9266
# Epoch 27/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9278
# Epoch 27: val_accuracy improved from 0.92662 to 0.92874, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 112ms/step - loss: 0.0455 - accuracy: 0.9278 - val_loss: 0.1390 - val_accuracy: 0.9287
# Epoch 28/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9299
# Epoch 28: val_accuracy improved from 0.92874 to 0.93093, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 105ms/step - loss: 0.0380 - accuracy: 0.9299 - val_loss: 0.1490 - val_accuracy: 0.9309
# Epoch 29/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9320
# Epoch 29: val_accuracy improved from 0.93093 to 0.93290, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 108ms/step - loss: 0.0200 - accuracy: 0.9320 - val_loss: 0.1879 - val_accuracy: 0.9329
# Epoch 30/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9340
# Epoch 30: val_accuracy improved from 0.93290 to 0.93487, saving model to ./seq2seq_kor/weights.h5
# 9/9 [==============================] - 1s 116ms/step - loss: 0.0145 - accuracy: 0.9340 - val_loss: 0.2136 - val_accuracy: 0.9349

# %% [markdown]
# ## 결과 플롯

# %%
plot_graphs(history, 'accuracy')

# %%
plot_graphs(history, 'loss')

# %% [markdown]
# ### 결과 확인

# %%
SAVE_FILE_NM = "weights.h5"
model.load_weights(os.path.join(DATA_OUT_PATH, MODEL_NAME, SAVE_FILE_NM))

# %%
query = "남자친구 승진 선물로 뭐가 좋을까?"

test_index_inputs, _ = enc_processing([query], char2idx)    
predict_tokens = model.inference(test_index_inputs)
print(predict_tokens)

print(' '.join([idx2char[str(t)] for t in predict_tokens]))
# Out:
# [104  38  97 110]
# 평소에 필요한 것 같아요

# %%
from langchain.sql_database import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///Chinook.db")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File F:\Anaconda3_envs\tensor2\lib\site-packages\aiohttp\client.py:92
#      91 try:
# ---> 92     import cchardet as chardet
#      93 except ImportError:  # pragma: no cover
#
# ModuleNotFoundError: No module named 'cchardet'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain.sql_database import SQLDatabase
#       3 db = SQLDatabase.from_uri("sqlite:///Chinook.db")
#
# File F:\Anaconda3_envs\tensor2\lib\site-packages\langchain\sql_database.py:2
#       1 """Keep here for backwards compatibility."""
# ----> 2 from langchain_community.utilities.sql_database import SQLDatabase
#       4 __all__ = ["SQLDatabase"]
#
# ...

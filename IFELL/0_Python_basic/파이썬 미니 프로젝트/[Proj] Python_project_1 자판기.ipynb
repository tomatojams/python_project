# %% [markdown]
# # Python 미니 프로젝트
# * 자판기 제작하기
# ```Python
# menus = ['콜라', '사이다', '생수', '커피']
# prices = [1200, 1200, 600, 300]
# ```
# * 위와 같이 메뉴와 가격이 있을 때, 사용자가 직접 돈과 메뉴를 입력해 만들어주는 프로젝트입니다.
#
# * 아래 메뉴를 참고해주세요.
# ```python
# 메뉴:
# 1 콜라 1000
# 2 사이다 1000
# 3 생수 600
# 4 커피 300
# ```
# * 프로그램 동작 순서
#     1. 메뉴 데이터 입력
#     2. 돈 입력
#     3. 메뉴 선택
#     4. 돈이 충분하면 메뉴와 거스름돈 출력, 부족하면 잔액이 부족하다는 알림 출력

# %%
menus = ['콜라', '사이다', '생수', '커피']
prices = [1200, 1200, 600, 300]

print('메뉴:')
for i, (# TODO) in enumerate(zip(# TODO)):
    print(# TODO)

money = # TODO #돈을 투입하세요: 2000
choice =  # TODO #메뉴를 선택하세요: 1

menu = #
price = #

if # TODO <= # TODO:
    print('선택 메뉴:', menu) #선택 메뉴: 콜라
    print('메뉴 가격:', price) #메뉴 가격: 1200
    print('거스름 돈:', money - price) #거스름 돈: 800
else:
    print('잔액이 부족합니다')

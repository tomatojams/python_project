# %% [markdown]
# # Python 미니 프로젝트
# * 주사위 게임 프로젝트입니다.
# * 컴퓨터와 사용자의 이름을 설정 합니다.
# * 주사위를 굴릴 수 있는 함수를 설정합니다.
#
# * while 문을 이용해서 연속으로 게임을 실행합니다.
#     1. 컴퓨터와 유저가 주사위를 굴립니다.
#     2. 더 큰수가 나온 사람이 승리합니다.
#     3. 분기문을 이용하여 게임을 반복할지를 결정합니다.

# %%
import random

# 컴퓨터와 사용자 이름 설정
computer_name = "Computer"
user_name = input("사용자 이름을 입력하세요: ")

# 주사위 굴리기 함수
def roll_dice():
    return random.randint(#TODO)

# 주사위 게임 실행
while True: # 무한 반복문
    # 컴퓨터와 사용자 주사위 굴리기
    computer_roll = #TODO
    user_roll = #TODO

    # 주사위 결과 출력
    print(f"{computer_name}: {computer_roll}")
    print(f"{user_name}: {user_roll}")

    # 더 큰 수를 가진 사람 출력
    if #TODO:
        print(f"{computer_name} 승리!")
    elif #TODO:
        print(f"{user_name} 승리!")
    else:
        print("무승부!")

    # 게임 종료 여부 확인
    play_again = input("게임을 다시 시작하시겠습니까? (y/n): ")
    if play_again.lower() != 'y':
        break

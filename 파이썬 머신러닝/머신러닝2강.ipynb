# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# 데이타생성
x = np.linspace(0, 10, 100) #구간 시작점, 구간 끝점, 구간 내 숫자 개수 구간 내에 숫자를 균일한 간격으로 촘촘하게 채울 수 있는 np.linspace 
#간격이 촘촘할수록 그래프를 그리는 상황 등에서 실제 그래프 개형과 더 가까워진다는 장점이 있지만, 어레이 사이즈가 커져서 다루기 힘들어질 수 있다는 단점이 있습니다.
y = 4 + 2*np.sin(2*x)

#Figure 객체를 생성하고 
#해당 Figure 객체에 여러 개의 AxesSubplot 객체를 생성하는 두 가지 작업을 한번에 하고자 할 때는 다음과 같이 plt.subplots를 사용하면 됩니다.

fig, ax = plt.subplots() 


ax.plot(x,y ,linewidth = 5.0)

ax.set(xlim=(0, 8), xticks=np.arange(2, 6), #lim 눈끔의 범위가 0~8 # tick - 눈끔 하나하나 1~7(마지막전)
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.grid()
plt.show()

# %%
# 데이터 로딩
from google.colab import drive
drive.mount('/content/drive')

ad = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data/Advertising.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 데이터 로딩
# ----> 2 from google.colab import drive
#       3 drive.mount('/content/drive')
#       5 ad = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data/Advertising.csv")
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
ad
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# 데이터 생성
tv = ad["TV"]
radio = ad["Radio"]
news = ad["Newspaper"]
sales = ad["Sales"]

#plot
fig, ax = plt.subplots()

ax.plot(tv,linewidth =1.0)
ax.plot(radio,linewidth =1.0)
ax.plot(news,linewidth =1.0)
ax.plot(sales,linewidth =1.0)

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # 데이터 생성
# ----> 2 tv = ad["TV"]
#       3 radio = ad["Radio"]
#       4 news = ad["Newspaper"]
#
# NameError: name 'ad' is not defined

# %% [markdown]
# **scatter() 예제**

# %%
np.random.seed(42)
x = 4 + np.random.normal(0, 2, 24) #정규분포 평균 0 표준편차 2 의 24개 데이타 생성
y = 4 + np.random.normal(0, 2, len(x))

sizes = np.random.uniform(15, 80, len(x)) # 균등분포 15~80사이에서 24개를 생성
colors = np.random.uniform(15, 80, len(x))

fig, ax = plt.subplots()

ax.scatter(x,y, s=sizes, c=colors)

ax.set(xlim = (0,8), xticks=np.arange(1,8),
       ylim = (0,8), yticks=np.arange(1,8))

plt.grid()
plt.show()

# %% [markdown]
# **Advertising data 적용**

# %%
#Tv 광고예산과 판매량의 관계

fig, ax = plt.subplots()

ax.scatter(tv, sales, s=5, c="blue")

ax.set(xlabel=("TV"),
       ylabel=("Sales")) #xlabel은 각축의 이름

plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(radio, sales, s=5, c="green")

ax.set(xlabel=("Radio"),
       ylabel=("Sales"))

plt.grid()
plt.show()

# %%
fig,ax =plt.subplots()

ax.scatter(news, sales, s=5, c="Red")

ax.set(xlabel=("Newspaper"),
       ylabel=("Sales"))

plt.grid()
plt.show()

# %% [markdown]
# **matplotlib 통계관련 plot**
# hist()

# %%
#데이타생성
np.random.seed(1)
x = 4 +np.random.normal(0, 1.5, 200)

#plot:
fig, ax = plt.subplots()

ax.hist(x, bins=20, linewidth=3, edgecolor="green") # bins 가로칸수, 선두께 엣지칼라=외곽선

ax.set(xlim=(0,8), xticks=np.arange(1,8),
       ylim=(0,56), yticks=np.linspace(0, 56, 9))

plt.grid()
plt.show()

# %% [markdown]
# **Advertising data에 적용**

# %%
fig, ax = plt.subplots()

ax.hist(tv, bins = 8, linewidth = 0.1, edgecolor ="white")

ax.set(xlabel=("TV"),
       ylabel=("Sales"))

plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()

ax.hist(news, bins = 8, linewidth = 0.1, edgecolor ="white")

ax.set(xlabel=("Newpaper"),
       ylabel=("Sales"))

plt.grid()
plt.show()

# %% [markdown]
# **boxplot()예제**

# %%
#데이타
np.random.seed(42)
D = np.random.normal((3, 5, 10), (1.25, 1.00, 1.25), (100,3)) #첫!) 세개모두 평균, 두번째 ()  세번째 데이타개수

#plot
fig, ax = plt.subplots()
ax.boxplot(D)

plt.grid()
plt.show()

# %%
D=[tv, radio, news]

flg, ax = plt.subplots()

ax.boxplot(D)

ax.set(xlabel =("Media"),
       ylabel =("Budget"))

plt.xticks([1, 2, 3],['TV', 'Radio', 'Newspaper']) # 1,2,3에 각문자가 대응해서 표시

plt.grid()
plt.show()

# %% [markdown]
# **seaborn 시작**

# %%
import seaborn as sns

# %% [markdown]
# relplot() -Advertising data

# %%
sns.relplot(x=tv, y=sales)

# %% [markdown]
# PairGrid - Advertising data

# %%
g = sns.PairGrid(ad)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %% [markdown]
# regression line - Advertising data

# %%
g=sns.PairGrid(ad, y_vars=["Sales"], x_vars=["TV", "Radio", "Newspaper"], height = 4)
g.map(sns.regplot, color =".3") #선형회귀선을 그리게 하기 regplot

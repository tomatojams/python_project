# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats

from matplotlib import pyplot as plt

import seaborn as sns

sns.set()
# %precision 3
# %matplotlib inline

# %% [markdown]
# 3.6.2 확률밀도 구하기

# %%
np.pi
# Out:
# 3.142

# %%
x = 3
mu = 4
sigma = 0.8
1/(np.sqrt(2*np.pi*sigma**2)) * np.exp(-((x-mu)**2) / (2*(sigma**2)))
# Out:
# 0.228

# %%
np.exp(1)
# Out:
# 2.718

# %%
stats.norm.pdf(loc = 4, scale = 0.8, x =3) # pdf 함수는 확률밀도를 계산해줌
# Out:
# 0.228

# %%
norm_dist = stats.norm(loc = 4, scale = 0.8) # 평균4 표준편차 0.8의 정규분포 인스턴스 생성
norm_dist.pdf( x= 3)
# Out:
# 0.228

# %%
x_plot = np.arange(start = 1, stop  = 7.1, step = 0.1)
plt.plot(x_plot, stats.norm.pdf(x = x_plot, loc= 4, scale = 0.8), color ='black')

# %%
np.random.seed(1)
simulated_sample = stats.norm.rvs( loc = 4, scale = 0.8, size = 100000)
simulated_sample
# Out:
# array([5.299, 3.511, 3.577, ..., 4.065, 4.275, 3.402])

# %%
np.sum(simulated_sample <=3)
# Out:
# 10371

# %%
np.sum(simulated_sample<=3) / len(simulated_sample)
# Out:
# 0.104

# %% [markdown]
# 3.6.4누적분포함수

# %%
stats.norm.cdf(loc =4, scale = 0.8, x =3)
# Out:
# 0.106

# %%
stats.norm.cdf(loc = 4, scale = 0.8, x =4)
# Out:
# 0.500

# %% [markdown]
# 3.6.5 하측확률과 퍼센트포인트

# %%
stats.norm.ppf(loc = 4, scale = 0.8, q = 0.025) # 확률을 고정하고 퍼센트포인트를 구함
# Out:
# 2.432

# %%
lower = stats.norm.cdf( loc =4, scale = 0.8, x = 3)
stats.norm.ppf(loc =4, scale = 0.8, q = lower)
# Out:
# 3.000

# %% [markdown]
# 3.6.6 표준정규분포 3.6.7 t값

# %%
np.random.seed(1)
t_value_array = np.zeros(10000)
norm_dist = stats.norm(loc =4, scale = 0.8)

for i in range(0, 10000):
    sample = norm_dist.rvs(size = 10)
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof = 1)
    sample_se = sample_std / np.sqrt(len(sample))
    t_value_array[i] = (sample_mean - 4)/ sample_se

# %%
sns.distplot(t_value_array, color = 'black')

x= np.arange(start = -8, stop = 8.1, step = 0.1)
plt.plot(x,stats.norm.pdf(x = x), color = 'black', linestyle = 'dotted')
# Out:
# C:\Users\tomat\AppData\Local\Temp\ipykernel_9728\3716948973.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(t_value_array, color = 'black')

# %% [markdown]
# 3.6.9 t분포

# %%
plt.plot(x, stats.norm.pdf(x = x), color = 'black', linestyle = 'dotted')
plt.plot(x, stats.t.pdf(x = x, df = 9), color = 'black')

# %%
sns.distplot(t_value_array, color = 'black', norm_hist = True)
plt.plot(x, stats.t.pdf(x = x, df = 9), color = 'black', linestyle = 'dotted')
# Out:
# C:\Users\tomat\AppData\Local\Temp\ipykernel_9728\3028722293.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(t_value_array, color = 'black', norm_hist = True)
